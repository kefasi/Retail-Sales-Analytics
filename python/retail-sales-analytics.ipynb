# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option("display.max_columns", None)

# Display up to 100 rows
pd.set_option("display.max_rows", 100)

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df = pd.read_excel("../data/raw/SuperstoreSales.xls")

# %%
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  Shipping Cost  \
# 0      0.04     Regular Air  -213.2500       38.94          35.00
# 1      0.07  Delivery Truck   457.8100      208.16          68.02
# 2      0.01     Regular Air    46.7075        8.69           2.99
# 3      0.08     Regular Air  1198.9710      195.99           3.99
# 4      0.08     Regular Air    30.9400       21.78           5.94
#
#         Customer Name Province   Region Customer Segment Product Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 8394    7765     55558 2010-08-09         Medium               8  1294.0400
# 8395    7766     55558 2010-08-09         Medium              23   392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37   823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8   469.8375
# 8398    7914     56581 2009-02-08           High              20  2026.0100
#
#       Discount       Ship Mode   Profit  Unit Price  Shipping Cost  \
# 8394      0.05  Delivery Truck -323.180      150.98          66.27
# 8395      0.04     Regular Air   22.250       17.07           8.13
# 8396      0.03     Express Air  343.050       22.23           5.08
# 8397      0.00     Regular Air -159.236       65.99           8.99
# 8398      0.10     Express Air  580.430      105.98          13.99
#
#         Customer Name Province Region Customer Segment Product Category  \
# ...

# %%
df.shift()
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0        NaN       NaN        NaT            NaN             NaN         NaN
# 1        1.0       3.0 2010-10-13            Low             6.0    261.5400
# 2       49.0     293.0 2012-10-01           High            49.0  10123.0200
# 3       50.0     293.0 2012-10-01           High            27.0    244.5700
# 4       80.0     483.0 2011-07-10           High            30.0   4965.7595
# ...      ...       ...        ...            ...             ...         ...
# 8394  7586.0   54279.0 2011-07-30           High            41.0  10071.0900
# 8395  7765.0   55558.0 2010-08-09         Medium             8.0   1294.0400
# 8396  7766.0   55558.0 2010-08-09         Medium            23.0    392.5700
# 8397  7906.0   56550.0 2011-04-08  Not Specified            37.0    823.7800
# 8398  7907.0   56550.0 2011-04-08  Not Specified             8.0    469.8375
#
# ...

# %%
df.shape
# Out:
# (8399, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   datetime64[us]
#  3   Order Priority        8399 non-null   str
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   str
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   str
#  12  Province              8399 non-null   str
#  13  Region                8399 non-null   str
#  14  Customer Segment      8399 non-null   str
# ...

# %%
df.describe()
# Out:
#             Row ID      Order ID                  Order Date  Order Quantity  \
# count  8399.000000   8399.000000                        8399     8399.000000
# mean   4200.000000  29965.179783  2010-12-25 00:40:58.578402       25.571735
# min       1.000000      3.000000         2009-01-01 00:00:00        1.000000
# 25%    2100.500000  15011.500000         2009-12-20 00:00:00       13.000000
# 50%    4200.000000  29857.000000         2010-12-17 00:00:00       26.000000
# 75%    6299.500000  44596.000000         2012-01-01 12:00:00       38.000000
# max    8399.000000  59973.000000         2012-12-30 00:00:00       50.000000
# std    2424.726789  17260.883447                         NaN       14.481071
#
#               Sales     Discount        Profit   Unit Price  Shipping Cost  \
# count   8399.000000  8399.000000   8399.000000  8399.000000    8399.000000
# mean    1775.878179     0.049671    181.184422    89.346259      12.838557
# ...

# %%
df_cleaned = df.copy()

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned = df_cleaned.drop_duplicates()

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned.isnull().sum()
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# dtype: int64

# %%
df_cleaned["Product Base Margin"] = df_cleaned["Product Base Margin"].fillna(0)

# %%
df_cleaned.isnull().sum()
# Out:
# Row ID                  0
# Order ID                0
# Order Date              0
# Order Priority          0
# Order Quantity          0
# Sales                   0
# Discount                0
# Ship Mode               0
# Profit                  0
# Unit Price              0
# Shipping Cost           0
# Customer Name           0
# Province                0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# Product Container       0
# Product Base Margin     0
# Ship Date               0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   datetime64[us]
#  3   Order Priority        8399 non-null   str
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   str
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   str
#  12  Province              8399 non-null   str
#  13  Region                8399 non-null   str
#  14  Customer Segment      8399 non-null   str
# ...

# %%
df_cleaned['Order Date'] = pd.to_datetime(df_cleaned['Order Date'])
df_cleaned['Ship Date'] = pd.to_datetime(df_cleaned['Ship Date'])

# %%
df_cleaned['Year'] = df_cleaned['Order Date'].dt.year

# %%
df_cleaned['Month'] = df_cleaned['Order Date'].dt.month_name()

# %%
df_cleaned['Profit Margin'] = df_cleaned['Profit'] / df_cleaned['Sales']

# %%
df_cleaned['Day of Week'] = df_cleaned['Order Date'].dt.day_name()

# %%
df_cleaned.replace([np.inf, -np.inf], 0, inplace=True)
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
df_cleaned['Sales'].sum()
# Out:
# np.float64(14915600.824000001)

# %%
df_cleaned['Profit'].sum()
# Out:
# np.float64(1521767.9595809998)

# %%
df_cleaned['Profit'].sum() / df_cleaned['Sales'].sum()
# Out:
# np.float64(0.10202525379550206)

# %%
df_cleaned.to_csv("../data/cleaned/superstore_cleaned.csv", index=False)

# %%
df_cleaned.to_excel("../data/cleaned/superstore_cleaned.xlsx", index=False)

# %%
df_cleaned["Order ID"].nunique()
# Out:
# 5496

# %%
df_cleaned["Sales"].mean()
# Out:
# np.float64(1775.8781788308133)

# %%
df_cleaned.groupby("Region")["Sales"].sum().sort_values(ascending=False).plot(kind="bar", title="Total Sales by Region")
# Out:
# <Axes: title={'center': 'Total Sales by Region'}, xlabel='Region'>

# %%
df_cleaned.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# West                     3.597549e+06
# Ontario                  3.063212e+06
# Prarie                   2.837305e+06
# Atlantic                 2.014248e+06
# Quebec                   1.510195e+06
# Yukon                    9.758674e+05
# Northwest Territories    8.008473e+05
# Nunavut                  1.163765e+05
# Name: Sales, dtype: float64

# %%
df_cleaned.groupby("Region")["Profit"].sum().sort_values(ascending=False)
# Out:
# Region
# Ontario                  346868.581175
# Prarie                   321160.180400
# West                     297008.576030
# Atlantic                 238960.612930
# Quebec                   140426.594746
# Northwest Territories    100653.051900
# Yukon                     73849.245400
# Nunavut                    2841.117000
# Name: Profit, dtype: float64

# %%
df_cleaned.groupby("Product Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Product Category
# Technology         5984248.182
# Furniture          5178590.542
# Office Supplies    3752762.100
# Name: Sales, dtype: float64

# %%
df_cleaned.groupby("Product Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Product Category
# Technology         886313.515300
# Office Supplies    518021.458000
# Furniture          117432.986281
# Name: Profit, dtype: float64

# %%
df_cleaned.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Global Troy™ Executive Leather Low-Back Tilter                   275941.520
# Polycom ViewStation™ ISDN Videoconferencing Unit                 255303.970
# Canon PC940 Copier                                               210910.680
# Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish    206494.130
# Hewlett Packard LaserJet 3310 Copier                             194880.350
# Bretford CR8500 Series Meeting Room Furniture                    147412.212
# Sharp AL-1530CS Digital Copier                                   130046.810
# Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers      128100.430
# GBC DocuBind 200 Manual Binding Machine                          120342.740
# Canon imageCLASS 2200 Advanced Copier                            114173.410
# Name: Sales, dtype: float64

# %%
df_cleaned.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Emily Phan           117124.4380
# Deborah Brumfield     97433.1355
# Roy Skaria            92542.1530
# Sylvia Foulston       88875.7575
# Grant Carroll         88417.0025
# Alejandro Grove       83561.9300
# Darren Budd           81577.3435
# Julia Barnett         80044.4520
# John Lucas            79696.1875
# Liz MacKendrick       76306.4315
# Name: Sales, dtype: float64

# %%
df_cleaned.groupby("Month")["Sales"].sum().sort_values(ascending=False)
# Out:
# Month
# December     1.467490e+06
# January      1.444923e+06
# October      1.383714e+06
# September    1.337957e+06
# March        1.273681e+06
# April        1.216483e+06
# February     1.180084e+06
# November     1.163393e+06
# May          1.160896e+06
# July         1.141104e+06
# August       1.115015e+06
# June         1.030859e+06
# Name: Sales, dtype: float64

# %%
df_cleaned.groupby("Month")["Sales"].sum().sort_values(ascending=False).plot(kind='pie', figsize=(10,6), title='Sales Distribution by Month', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Sales Distribution by Month'}>

# %%
monthly_sales = (df_cleaned.groupby(df_cleaned["Order Date"].dt.to_period("M"))["Sales"].sum()).plot(kind="bar", title="Monthly Sales Trend", figsize=(12,6), ylabel="Total Sales", xlabel="Month")

# %%
plt.figure(figsize=(14,8))
plt.scatter(df_cleaned["Sales"], df_cleaned["Profit"], alpha=0.5, )
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df_cleaned["Discount"], df_cleaned["Profit"], alpha=0.5)

plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")

plt.show()

# %%
df_cleaned[["Sales", "Profit", "Order Quantity", "Discount"]].corr()
# Out:
#                    Sales    Profit  Order Quantity  Discount
# Sales           1.000000  0.581960        0.220582 -0.019686
# Profit          0.581960  1.000000        0.194655 -0.037128
# Order Quantity  0.220582  0.194655        1.000000 -0.009649
# Discount       -0.019686 -0.037128       -0.009649  1.000000

# %%
df_cleaned.groupby("Product Name")["Profit"].mean().sort_values(ascending=False).head(10).plot(kind='barh', figsize=(12,6), title='Average Profit by Product', xlabel='Average Profit', ylabel='Product Name')
# Out:
# <Axes: title={'center': 'Average Profit by Product'}, xlabel='Average Profit', ylabel='Product Name'>

# %%
df_cleaned.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).head(10)
